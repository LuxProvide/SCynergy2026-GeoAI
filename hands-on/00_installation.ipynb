# %%
# !which python
# !which pip

# %%
# !pip install --upgrade pip

# %%
# Notebook 01 
# !pip install geopandas planetary_computer matplotlib

# Notebook 02 (on top of Notebook 01)
# !pip install rasterio tqdm

# Notebook 03 (on top of Notebooks 01 & 02)
# !pip install terratorch

# %%
# TerraMind Tutorial Notebook (Sen1Floods11)
# !pip install gdown
